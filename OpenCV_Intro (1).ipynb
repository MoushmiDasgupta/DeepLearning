# %%
import cv2

# %%
cv2.__version__
# Out:
# '4.1.2'

# %%
import numpy as np

# %%
# Please use your own image files which you need to upload to your google drive and then link the path to this file like below

# %%
img = cv2.imread("/content/drive/MyDrive/Colab Notebooks/CNN/preview16.jpg")
img
# Out:
# array([[[  2,  83,  58],
#         [ 11,  92,  67],
#         [ 15,  92,  65],
#         ...,
#         [125, 165, 154],
#         [126, 164, 152],
#         [118, 156, 144]],
#
#        [[ 16,  97,  72],
#         [ 21, 102,  77],
#         [ 20,  97,  70],
#         ...,
#         [121, 161, 150],
#         [113, 151, 139],
#         [104, 142, 130]],
#
#        [[ 24, 105,  80],
#         [ 27, 108,  83],
#         [ 23, 100,  73],
#         ...,
#         [108, 145, 135],
#         [ 98, 134, 122],
#         [ 87, 123, 111]],
#
#        ...,
#
#        [[ 33, 139, 103],
#         [ 32, 138, 102],
#         [ 28, 136, 100],
#         ...,
#         [ 85, 135, 158],
#         [115, 163, 187],
#         [128, 176, 200]],
#
#        [[ 36, 142, 106],
#         [ 34, 140, 104],
#         [ 31, 139, 103],
#         ...,
#         [ 79, 129, 152],
#         [115, 163, 187],
#         [129, 177, 201]],
#
#        [[ 41, 147, 111],
#         [ 39, 145, 109],
#         [ 35, 143, 107],
# ...

# %%
from google.colab.patches import cv2_imshow

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=890x500 at 0x7F8ADB10AC90>

# %%
img.shape
# Out:
# (500, 890, 3)

# %%
import matplotlib.pyplot as plt
plt.imshow(img)

# %%
image_bw = cv2.imread("/content/drive/MyDrive/Colab Notebooks/CNN/preview16.jpg",0)
cv2_imshow(image_bw)
# Out:
# <PIL.Image.Image image mode=L size=890x500 at 0x7F8ADB10D9D0>

# %%
image_bw.shape
# Out:
# (500, 890)

# %%
image_grey = cv2.imread("/content/drive/MyDrive/Colab Notebooks/CNN/preview16.jpg",cv2.IMREAD_GRAYSCALE)
cv2_imshow(image_grey)
# Out:
# <PIL.Image.Image image mode=L size=890x500 at 0x7F8ADB07A450>

# %%
image_grey.shape
# Out:
# (500, 890)

# %%
image_grey_8 = cv2.imread("/content/drive/MyDrive/Colab Notebooks/CNN/preview16.jpg",cv2.IMREAD_REDUCED_GRAYSCALE_8)
cv2_imshow(image_grey_8)
# Out:
# <PIL.Image.Image image mode=L size=112x63 at 0x7F8ADB0C6D10>

# %%
image_grey_8.shape
# Out:
# (63, 112)

# %%
image_color_8 = cv2.imread("/content/drive/MyDrive/Colab Notebooks/CNN/preview16.jpg",cv2.IMREAD_REDUCED_COLOR_4)
cv2_imshow(image_color_8)
# Out:
# <PIL.Image.Image image mode=RGB size=223x125 at 0x7F8ADB08E710>

# %%
image_color_8.shape
# Out:
# (125, 223, 3)

# %%
cv2.imwrite("/content/drive/MyDrive/Colab Notebooks/CNN/smallimg.jpg",image_color_8)
# Out:
# True

# %%
cv2.imwrite("/content/drive/MyDrive/Colab Notebooks/CNN/smallgrey.jpg",image_color_8)
# Out:
# True

# %%
colorimage = cv2.cvtColor(image_bw,cv2.COLOR_BAYER_BG2BGR)
colorimage
plt.imshow(colorimage)

# %%
colorimage = cv2.cvtColor(image_bw,cv2.COLOR_BAYER_GB2BGR)
colorimage
plt.imshow(colorimage)

# %%
blurimage = cv2.blur(img,(100,100))
cv2_imshow(blurimage)
# Out:
# <PIL.Image.Image image mode=RGB size=890x500 at 0x7F8AD285B0D0>

# %%
blurimage.shape
# Out:
# (500, 890, 3)
